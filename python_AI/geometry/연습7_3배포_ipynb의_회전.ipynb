# %%
from google.colab.patches import cv2_imshow
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab import drive
'''
일정 각도로 영상을 회전
중심을 메트릭스2d를 사용하려 새로 잡고 회전
'''
drive.mount('/content/gdrive') 
#영상 불러오기
img = cv2.imread('/content/gdrive/My Drive/Image_Processing/airplane.bmp')

rows,cols = img.shape[:2] 
# 회전점을 영상 모서리 -> 영상의 중심으로 변경
M = cv2.getRotationMatrix2D(((cols-1)/2.0,(rows-1)/2.0),-40,1)
'''
영상의 회전 중심, 회전각도(양수는 시계반대방향), 등방성 스케일계수

'''
output_img = cv2.warpAffine(img,M,(cols*1,rows*1),flags = cv2.INTER_LINEAR)
'''
입력 영상, 출력영상(없음), m변환행렬, 출력 영상 크기,  flags: 보간법
'''
#그림을 화면에 출력 (원래 영상 크기대로 출력)
print("original image",img.shape[:2] )
cv2_imshow(img)
print("Rotation Transformation",output_img.shape[:2])
cv2_imshow(output_img)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# original image (210, 320)
# <PIL.Image.Image image mode=RGB size=320x210 at 0x7F58C6EF8890>
# Rotation Transformation (210, 320)
# <PIL.Image.Image image mode=RGB size=320x210 at 0x7F58C6EF8850>
